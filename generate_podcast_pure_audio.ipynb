# %%
from podcast_data_preparation import PodcastDataPreparation
from video_crafter import VideoCrafter

EPISODE_INDEX = 3
data_json_path = f'D:\Study\AIAgent\AIPodcast\output\episode_{EPISODE_INDEX}\episode_{EPISODE_INDEX}_data.json'
output_dir = f'D:\Study\AIAgent\AIPodcast\output\episode_{EPISODE_INDEX}'
preparation = PodcastDataPreparation(data_json_path, output_dir)
video_info_config = preparation.prepare_pure_audio_data()
import json
print(json.dumps(video_info_config, indent=4, ensure_ascii=False))
# Out:
# Downloaded https://lf-bot-studio-plugin-resource.coze.cn/obj/bot-studio-platform-plugin-tos/sami/tts/931b59c3aa8e481e86cf78f9d72f307d.mp3 to D:\Study\AIAgent\AIPodcast\output\episode_3\downloaded_audios\931b59c3aa8e481e86cf78f9d72f307d.mp3
# Downloaded https://lf-bot-studio-plugin-resource.coze.cn/obj/bot-studio-platform-plugin-tos/sami/tts/729dc98766ca4334afec590c7eeadd11.mp3 to D:\Study\AIAgent\AIPodcast\output\episode_3\downloaded_audios\729dc98766ca4334afec590c7eeadd11.mp3
# Downloaded https://lf-bot-studio-plugin-resource.coze.cn/obj/bot-studio-platform-plugin-tos/sami/tts/08cc336730e44511988b65703c935258.mp3 to D:\Study\AIAgent\AIPodcast\output\episode_3\downloaded_audios\08cc336730e44511988b65703c935258.mp3
# Downloaded https://lf-bot-studio-plugin-resource.coze.cn/obj/bot-studio-platform-plugin-tos/sami/tts/e3e262461e754287a3e1cf974ab212f4.mp3 to D:\Study\AIAgent\AIPodcast\output\episode_3\downloaded_audios\e3e262461e754287a3e1cf974ab212f4.mp3
# ...

# %%
crafter = VideoCrafter(video_info_config)
crafter.create()
# Out:
# MoviePy - Writing audio in D:\Study\AIAgent\AIPodcast\output\episode_3\output.mp3
# MoviePy - Done.
